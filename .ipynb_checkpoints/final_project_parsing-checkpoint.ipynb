# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
jobs = pd.read_csv("job_training_data.csv")
jobs
# Out:
#       job_id                                              title  \
# 0      13454                        Field Operations Specialist
# 1      11411  CM2 5AS Warehousing apprenticeship available u...
# 2      15153                                     Lead QA Tester
# 3       2814          Basingstoke Fragrance/Beauty Staff Needed
# 4      13996                                   Swim Instructor
# ...      ...                                                ...
# 5357   17632                  Property Preservation Field Crews
# 5358   17751                           Administrative Assistant
# 5359   17561         Job for freelancer working in Saudi Arabia
# 5360    2397                                Senior QA Engineer
# 5361    5026                         Call Center Representative
#
#                     location                    department salary_range  \
# 0            US, SD, Yankton                           NaN          NaN
# ...

# %%
fraud = jobs[jobs["fraudulent"] == 1]
fraud.to_csv("fraudulent.csv",index = False)

# %%
not_fraud = jobs[jobs["fraudulent"] == 0]
not_fraud.to_csv("not_fraudulent.csv",index = False)

# %%
len(not_fraud["required_education"].unique())
# Out:
# 13

# %%
len(fraud["required_education"].unique())
# Out:
# 11

# %%
sns.histplot(data = not_fraud, x="required_education")
# Out:
# <AxesSubplot:xlabel='required_education', ylabel='Count'>

# %%
sns.histplot(data= fraud, x="required_education")
# Out:
# <AxesSubplot:xlabel='required_education', ylabel='Count'>

# %%
not_fraud["industry"].value_counts()[:20]
# Out:
# Information Technology and Services    562
# Computer Software                      414
# Internet                               339
# Education Management                   243
# Marketing and Advertising              234
# Financial Services                     226
# Hospital & Health Care                 123
# Consumer Services                      100
# Telecommunications                      95
# Oil & Energy                            61
# Retail                                  60
# Real Estate                             55
# Automotive                              45
# Construction                            41
# Insurance                               37
# Staffing and Recruiting                 36
# Accounting                              33
# Health, Wellness and Fitness            32
# Logistics and Supply Chain              32
# Design                                  31
# Name: industry, dtype: int64

# %%
fraud["industry"].value_counts()[:20]
# Out:
# Oil & Energy                            32
# Hospital & Health Care                  20
# Accounting                              18
# Financial Services                      17
# Marketing and Advertising               15
# Real Estate                             10
# Telecommunications                       8
# Health, Wellness and Fitness             6
# Hospitality                              6
# Information Technology and Services      6
# Consumer Services                        5
# Computer Networking                      4
# Media Production                         3
# Human Resources                          3
# Staffing and Recruiting                  2
# Management Consulting                    2
# Biotechnology                            2
# Leisure, Travel & Tourism                2
# Mechanical or Industrial Engineering     2
# Banking                                  2
# Name: industry, dtype: int64
